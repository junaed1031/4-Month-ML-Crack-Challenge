# %%
x = 10

def change_x():
    x = 20

change_x()
print(x)
# Out:
# 10

# %%
def add(a, b):
    print(a + b)

res = add(5, 5)
print(res)
# Out:
# 10
# None

# %%
def connect(port=3306):
    print(f"Connecting to {port}")

connect()
connect(5432)
# Out:
# Connecting to 3306
# Connecting to 5432

# %%
def is_even(num):
    return num % 2 == 0

print(is_even(4))
print(is_even(7))
# Out:
# True
# False
