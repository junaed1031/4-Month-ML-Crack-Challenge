# %%
a = [1, 2, 3]
b = a

b[0] = 99

print(a)
# Out:
# [99, 2, 3]

# %%
data = [10, 20, 30, 40, 50]

result = data[-1:-4:-1]

print(result)
# Out:
# [50, 40, 30]

# %%
stack = []

stack.append(1)
stack.append(2)
stack.append(3)

last_item = stack.pop()

print(last_item)
# Out:
# 3

# %%
result = [x**2 for x in range(1, 11) if x % 2 == 0]

print(result)
# Out:
# [4, 16, 36, 64, 100]
