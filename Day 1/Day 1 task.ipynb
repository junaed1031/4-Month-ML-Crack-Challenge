# %%
print ("Junaed")
# Out:
# Junaed

# %%
x = 100
y = 200
x , y = y , x
print("x =", x ,"y =", y)
# Out:
# x = 200 y = 100

# %%
A = input("Input a number:")
print(A)
print(type(A))
A_float = float(A)
print(type(A_float))
# Out:
# 10
# <class 'str'>
# <class 'float'>

# %%
value = 500/3
print ( "value is : $",format(value, ".3f") )
# Out:
# value is : $ 166.667

# %%
second = input ("Enter seconds: ")
Houres = int (second) // 3600
remain_second = int (second) % 3600
Min = remain_second // 60
Sec = remain_second % 60
print (Houres, ":", Min, ":", Sec)
# Out:
# 600
# 0
# 600
# 10
# 0 : 10 : 0
